# %%
import pandas as pd
from kmodes.kmodes import KModes

# %%
df = pd.read_excel('Datasets/Dataset_w_labels.xlsx')

# %%
df
# Out:
#        age  gender     ethnicity             race    education marital_status  \
# 0    45-54  female  non hispanic  native american  High School    undisclosed
# 1    18-24    male      hispanic            white  High School         single
# 2    25-34  female  non hispanic      multiracial    Associate         single
# 3    25-34  female      hispanic      undisclosed    Associate         single
# 4    18-24    male      hispanic  native american     Bachelor         single
# ..     ...     ...           ...              ...          ...            ...
# 395     na  female  non hispanic            black    Associate        married
# 396  25-34    male  non hispanic            white    Associate         single
# 397  25-34  female      hispanic            white     Bachelor         single
# 398  25-34    male  non hispanic            black     Bachelor         single
# 399  25-34    male  non hispanic            black     Bachelor        married
#
#               income          employment language                  disability  \
# 0      25000 - 49999  Employed Part time     both  i do not have a disability
# 1    Less than 25000  Employed Part time  english  i do not have a disability
# 2    Less than 25000             Student  english  i do not have a disability
# 3    Less than 25000  Employed Part time     both  i do not have a disability
# 4      25000 - 49999             Student     both                 undisclosed
# ..               ...                 ...      ...                         ...
# 395  Less than 25000  Employed Full time  english  i do not have a disability
# 396    25000 - 49999       Self employed  english  i do not have a disability
# 397      undisclosed             Student     both  i do not have a disability
# 398    50000 - 74999  Employed Part time     both  i do not have a disability
# 399    50000 - 74999  Employed Full time  english  i do not have a disability
#
#          choice  Cluster
# 0    Persuasive        2
# 1      Original        2
# 2      Original        2
# 3    Empathetic        2
# 4    Empathetic        3
# ..          ...      ...
# 395  Empathetic        0
# 396  Persuasive        0
# 397    Simplier        2
# 398  Persuasive        0
# 399  Persuasive        0
#
# [400 rows x 12 columns]

# %%
df.drop('Cluster', axis=1, inplace=True)

# %% [markdown]
# ## K-Modes

# %%
import matplotlib.pyplot as plt

# %%
# Elbow curve to find optimal K 
cost = [] 
K = range(1,10) 
for k in list(K): 
    kmode = KModes(n_clusters=k, init = "random", n_init = 5, verbose=1) 
    kmode.fit_predict(df) 
    cost.append(kmode.cost_) 
      
plt.plot(K, cost, 'x-') 
plt.xlabel('No. of clusters') 
plt.ylabel('Cost') 
plt.title('Elbow Curve') 
plt.show()
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 2322.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 2322.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 2322.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 2322.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 2322.0
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 84, cost: 2061.0
# Run 1, iteration: 2/100, moves: 18, cost: 2061.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 87, cost: 1917.0
# Run 2, iteration: 2/100, moves: 14, cost: 1917.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 40, cost: 1914.0
# Run 3, iteration: 2/100, moves: 3, cost: 1914.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 60, cost: 1919.0
# Run 4, iteration: 2/100, moves: 0, cost: 1919.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 93, cost: 1926.0
# Run 5, iteration: 2/100, moves: 48, cost: 1926.0
# Best run was number 3
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 98, cost: 1818.0
# Run 1, iteration: 2/100, moves: 34, cost: 1805.0
# Run 1, iteration: 3/100, moves: 2, cost: 1805.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 96, cost: 1765.0
# Run 2, iteration: 2/100, moves: 6, cost: 1765.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 104, cost: 1924.0
# Run 3, iteration: 2/100, moves: 18, cost: 1924.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 59, cost: 1836.0
# Run 4, iteration: 2/100, moves: 2, cost: 1836.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 48, cost: 1912.0
# Run 5, iteration: 2/100, moves: 64, cost: 1847.0
# Run 5, iteration: 3/100, moves: 35, cost: 1841.0
# Run 5, iteration: 4/100, moves: 1, cost: 1841.0
# Best run was number 2
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 159, cost: 1610.0
# Run 1, iteration: 2/100, moves: 34, cost: 1610.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 130, cost: 1714.0
# Run 2, iteration: 2/100, moves: 30, cost: 1714.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 81, cost: 1748.0
# Run 3, iteration: 2/100, moves: 24, cost: 1723.0
# Run 3, iteration: 3/100, moves: 21, cost: 1723.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 85, cost: 1699.0
# Run 4, iteration: 2/100, moves: 73, cost: 1682.0
# Run 4, iteration: 3/100, moves: 4, cost: 1682.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 69, cost: 1684.0
# Run 5, iteration: 2/100, moves: 22, cost: 1678.0
# Run 5, iteration: 3/100, moves: 26, cost: 1653.0
# Run 5, iteration: 4/100, moves: 15, cost: 1653.0
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 86, cost: 1549.0
# Run 1, iteration: 2/100, moves: 35, cost: 1530.0
# Run 1, iteration: 3/100, moves: 32, cost: 1519.0
# Run 1, iteration: 4/100, moves: 1, cost: 1519.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 54, cost: 1624.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 136, cost: 1569.0
# Run 3, iteration: 2/100, moves: 29, cost: 1569.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 110, cost: 1654.0
# Run 4, iteration: 2/100, moves: 40, cost: 1644.0
# Run 4, iteration: 3/100, moves: 3, cost: 1644.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 121, cost: 1576.0
# Run 5, iteration: 2/100, moves: 64, cost: 1540.0
# Run 5, iteration: 3/100, moves: 14, cost: 1540.0
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 160, cost: 1522.0
# Run 1, iteration: 2/100, moves: 62, cost: 1492.0
# Run 1, iteration: 3/100, moves: 19, cost: 1492.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 42, cost: 1548.0
# Run 2, iteration: 2/100, moves: 46, cost: 1479.0
# Run 2, iteration: 3/100, moves: 37, cost: 1479.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 101, cost: 1572.0
# Run 3, iteration: 2/100, moves: 39, cost: 1527.0
# Run 3, iteration: 3/100, moves: 35, cost: 1527.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 120, cost: 1496.0
# Run 4, iteration: 2/100, moves: 31, cost: 1479.0
# Run 4, iteration: 3/100, moves: 6, cost: 1479.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 77, cost: 1553.0
# Run 5, iteration: 2/100, moves: 5, cost: 1553.0
# Best run was number 2
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 57, cost: 1456.0
# Run 1, iteration: 2/100, moves: 68, cost: 1392.0
# Run 1, iteration: 3/100, moves: 6, cost: 1385.0
# Run 1, iteration: 4/100, moves: 2, cost: 1385.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 73, cost: 1458.0
# Run 2, iteration: 2/100, moves: 63, cost: 1411.0
# Run 2, iteration: 3/100, moves: 11, cost: 1411.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 144, cost: 1392.0
# Run 3, iteration: 2/100, moves: 31, cost: 1364.0
# Run 3, iteration: 3/100, moves: 15, cost: 1362.0
# Run 3, iteration: 4/100, moves: 2, cost: 1362.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 71, cost: 1567.0
# Run 4, iteration: 2/100, moves: 81, cost: 1517.0
# Run 4, iteration: 3/100, moves: 70, cost: 1414.0
# Run 4, iteration: 4/100, moves: 22, cost: 1414.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 114, cost: 1493.0
# Run 5, iteration: 2/100, moves: 84, cost: 1421.0
# Run 5, iteration: 3/100, moves: 31, cost: 1421.0
# Best run was number 3
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 73, cost: 1412.0
# Run 1, iteration: 2/100, moves: 37, cost: 1402.0
# Run 1, iteration: 3/100, moves: 17, cost: 1398.0
# Run 1, iteration: 4/100, moves: 1, cost: 1398.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 88, cost: 1413.0
# Run 2, iteration: 2/100, moves: 40, cost: 1393.0
# Run 2, iteration: 3/100, moves: 3, cost: 1393.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 91, cost: 1363.0
# Run 3, iteration: 2/100, moves: 16, cost: 1363.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 79, cost: 1318.0
# Run 4, iteration: 2/100, moves: 4, cost: 1318.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 92, cost: 1355.0
# Run 5, iteration: 2/100, moves: 16, cost: 1353.0
# Run 5, iteration: 3/100, moves: 0, cost: 1353.0
# Best run was number 4
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 75, cost: 1269.0
# Run 1, iteration: 2/100, moves: 28, cost: 1263.0
# Run 1, iteration: 3/100, moves: 0, cost: 1263.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 63, cost: 1405.0
# Run 2, iteration: 2/100, moves: 69, cost: 1382.0
# Run 2, iteration: 3/100, moves: 24, cost: 1376.0
# Run 2, iteration: 4/100, moves: 4, cost: 1376.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 80, cost: 1269.0
# Run 3, iteration: 2/100, moves: 36, cost: 1264.0
# Run 3, iteration: 3/100, moves: 13, cost: 1264.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 88, cost: 1277.0
# Run 4, iteration: 2/100, moves: 22, cost: 1263.0
# Run 4, iteration: 3/100, moves: 7, cost: 1257.0
# Run 4, iteration: 4/100, moves: 5, cost: 1253.0
# Run 4, iteration: 5/100, moves: 2, cost: 1253.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 14, cost: 1397.0
# Best run was number 4

# %%
kmodes = KModes(n_clusters=5, init='random', n_init=5, verbose=1)

# Fit the K-modes model
clusters = kmodes.fit_predict(df)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 58, cost: 1610.0
# Run 1, iteration: 2/100, moves: 55, cost: 1600.0
# Run 1, iteration: 3/100, moves: 6, cost: 1600.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 111, cost: 1581.0
# Run 2, iteration: 2/100, moves: 11, cost: 1581.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 84, cost: 1584.0
# Run 3, iteration: 2/100, moves: 24, cost: 1584.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 106, cost: 1581.0
# Run 4, iteration: 2/100, moves: 19, cost: 1581.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 86, cost: 1563.0
# Run 5, iteration: 2/100, moves: 2, cost: 1563.0
# Best run was number 5

# %%
df['Cluster'] = clusters

# %%
df
# Out:
#        age  gender     ethnicity             race    education marital_status  \
# 0    45-54  female  non hispanic  native american  High School    undisclosed
# 1    18-24    male      hispanic            white  High School         single
# 2    25-34  female  non hispanic      multiracial    Associate         single
# 3    25-34  female      hispanic      undisclosed    Associate         single
# 4    18-24    male      hispanic  native american     Bachelor         single
# ..     ...     ...           ...              ...          ...            ...
# 395     na  female  non hispanic            black    Associate        married
# 396  25-34    male  non hispanic            white    Associate         single
# 397  25-34  female      hispanic            white     Bachelor         single
# 398  25-34    male  non hispanic            black     Bachelor         single
# 399  25-34    male  non hispanic            black     Bachelor        married
#
#               income          employment language                  disability  \
# 0      25000 - 49999  Employed Part time     both  i do not have a disability
# 1    Less than 25000  Employed Part time  english  i do not have a disability
# 2    Less than 25000             Student  english  i do not have a disability
# 3    Less than 25000  Employed Part time     both  i do not have a disability
# 4      25000 - 49999             Student     both                 undisclosed
# ..               ...                 ...      ...                         ...
# 395  Less than 25000  Employed Full time  english  i do not have a disability
# 396    25000 - 49999       Self employed  english  i do not have a disability
# 397      undisclosed             Student     both  i do not have a disability
# 398    50000 - 74999  Employed Part time     both  i do not have a disability
# 399    50000 - 74999  Employed Full time  english  i do not have a disability
#
#          choice  Cluster
# 0    Persuasive        4
# 1      Original        1
# 2      Original        0
# 3    Empathetic        0
# 4    Empathetic        0
# ..          ...      ...
# 395  Empathetic        3
# 396  Persuasive        2
# 397    Simplier        0
# 398  Persuasive        2
# 399  Persuasive        2
#
# [400 rows x 12 columns]

# %%
print("Cluster centroids:\n", kmodes.cluster_centroids_)
# Out:
# Cluster centroids:
#  [['25-34' 'female' 'hispanic' 'Mexican' 'Associate' 'single'
#   'Less than 25000' 'Student' 'both' 'i do not have a disability'
#   'Empathetic']
#  ['45-54' 'male' 'hispanic' 'white' 'less than high school' 'single'
#   'Less than 25000' 'Employed Full time' 'english'
#   'i do not have a disability' 'Empathetic']
#  ['25-34' 'male' 'non hispanic' 'white' 'Bachelor' 'married'
#   '50000 - 74999' 'Retired' 'english' 'i do not have a disability'
#   'Persuasive']
#  ['25-34' 'female' 'non hispanic' 'white' 'Associate' 'married'
#   '25000 - 49999' 'Employed Full time' 'english'
#   'i do not have a disability' 'Simplier']
#  ['45-54' 'male' 'non hispanic' 'white' 'High School' 'married'
#   '25000 - 49999' 'Employed Part time' 'both'
#   'i do not have a disability' 'Original']]

# %%
from sklearn.metrics import silhouette_samples, silhouette_score, adjusted_rand_score
from scipy.spatial.distance import hamming

# %%
# Function to compute Silhouette Score using Hamming distance
def silhouette_score_hamming(data, clusters):
    hamming_distances = [[hamming(x, y) for y in data] for x in data]
    silhouette_avg = silhouette_samples(hamming_distances, clusters).mean()
    return silhouette_avg

# Compute Silhouette Score
silhouette_avg = silhouette_score_hamming(df.values, clusters)
print("Silhouette Score:", silhouette_avg)
# Out:
# Silhouette Score: 0.29322065286430826

# %% [markdown]
# ## K-Prototype
#
# **Description**:
# K-prototype is a clustering algorithm that combines k-means with k-modes to handle datasets with both numerical and categorical data. It assigns weights to both types of features and calculates a weighted distance metric to determine cluster assignments.

# %%
pro_data = pd.read_excel('Datasets/Dataset_K_prototypes.xlsx')

# %%
pro_data.drop('disability', axis=1, inplace=True)

# %%
pro_data
# Out:
#      age  gender     ethnicity             race    education marital_status  \
# 0      3  female  non hispanic  native american  High School    undisclosed
# 1      0    male      hispanic            white  High School         single
# 2      1  female  non hispanic      multiracial    Associate         single
# 3      1  female      hispanic      undisclosed    Associate         single
# 4      0    male      hispanic  native american     Bachelor         single
# ..   ...     ...           ...              ...          ...            ...
# 395   -1  female  non hispanic            black    Associate        married
# 396    1    male  non hispanic            white    Associate         single
# 397    1  female      hispanic            white     Bachelor         single
# 398    1    male  non hispanic            black     Bachelor         single
# 399    1    male  non hispanic            black     Bachelor        married
#
#      income          employment language      choice
# 0         1  Employed Part time     both  Persuasive
# 1         0  Employed Part time  english    Original
# 2         0             Student  english    Original
# 3         0  Employed Part time     both  Empathetic
# 4         1             Student     both  Empathetic
# ..      ...                 ...      ...         ...
# 395       0  Employed Full time  english  Empathetic
# 396       1       Self employed  english  Persuasive
# 397      -1             Student     both    Simplier
# 398       2  Employed Part time     both  Persuasive
# 399       2  Employed Full time  english  Persuasive
#
# [400 rows x 10 columns]

# %%
from kmodes.kprototypes import KPrototypes

# %%
categorical_indices = [1, 2, 3, 4, 5, 7, 8, 9, 10]

def calculate_cost(data, categorical_features, max_clusters=10):
    costs = []
    for k in range(1, max_clusters + 1):
        kproto = KPrototypes(n_clusters=k, init='Cao', verbose=0)
        kproto.fit_predict(data, categorical=categorical_features)
        costs.append(kproto.cost_)
    return costs

# Calculate costs for different numbers of clusters
max_clusters = 10
costs = calculate_cost(pro_data, categorical_indices, max_clusters)

# Plot the elbow plot
plt.plot(range(1, max_clusters + 1), costs, marker='o')
plt.xlabel('Number of Clusters')
plt.ylabel('Cost')
plt.title('Elbow Method for Optimal Number of Clusters')
plt.show()

# %%
kproto = KPrototypes(n_clusters=3, init='Cao', verbose=2)

# Fit the model to your data
clusters = kproto.fit_predict(pro_data, categorical=[1,2,3,4,5,7,8,9])  # Specify indices of categorical features
# Out:
# Initialization method and algorithm are deterministic. Setting n_init to 1.
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/100, moves: 105, ncost: 1522.1989790653922
# Run: 1, iteration: 2/100, moves: 37, ncost: 1493.1979780306583
# Run: 1, iteration: 3/100, moves: 7, ncost: 1490.1558193867982
# Run: 1, iteration: 4/100, moves: 1, ncost: 1490.127264230388
# Run: 1, iteration: 5/100, moves: 0, ncost: 1490.127264230388
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/100, moves: 22, ncost: 1470.9453555135503
# Run: 2, iteration: 2/100, moves: 3, ncost: 1470.9174745637438
# Run: 2, iteration: 3/100, moves: 0, ncost: 1470.9174745637438
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 3, iteration: 1/100, moves: 44, ncost: 1517.7534668146739
# Run: 3, iteration: 2/100, moves: 26, ncost: 1493.1167061094895
# Run: 3, iteration: 3/100, moves: 6, ncost: 1490.1558193867982
# Run: 3, iteration: 4/100, moves: 1, ncost: 1490.127264230388
# Run: 3, iteration: 5/100, moves: 0, ncost: 1490.127264230388
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 4, iteration: 1/100, moves: 64, ncost: 1729.7066128881008
# Run: 4, iteration: 2/100, moves: 39, ncost: 1668.730884927046
# Run: 4, iteration: 3/100, moves: 68, ncost: 1525.4461012692618
# Run: 4, iteration: 4/100, moves: 53, ncost: 1462.1171105603282
# Run: 4, iteration: 5/100, moves: 18, ncost: 1457.1708976449163
# Run: 4, iteration: 6/100, moves: 2, ncost: 1457.1278442555908
# Run: 4, iteration: 7/100, moves: 0, ncost: 1457.1278442555908
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 5, iteration: 1/100, moves: 64, ncost: 1460.489082806731
# Run: 5, iteration: 2/100, moves: 12, ncost: 1457.218128847909
# Run: 5, iteration: 3/100, moves: 2, ncost: 1457.1278442555908
# Run: 5, iteration: 4/100, moves: 0, ncost: 1457.1278442555908
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 6, iteration: 1/100, moves: 56, ncost: 1654.2629300941596
# Run: 6, iteration: 2/100, moves: 72, ncost: 1462.3202229151746
# Run: 6, iteration: 3/100, moves: 16, ncost: 1458.0944078208952
# Run: 6, iteration: 4/100, moves: 0, ncost: 1458.0944078208952
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 7, iteration: 1/100, moves: 115, ncost: 1466.0712489070502
# Run: 7, iteration: 2/100, moves: 20, ncost: 1458.0908150946602
# Run: 7, iteration: 3/100, moves: 0, ncost: 1458.0908150946602
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 8, iteration: 1/100, moves: 48, ncost: 1731.6918259634433
# Run: 8, iteration: 2/100, moves: 21, ncost: 1718.4641352891636
# Run: 8, iteration: 3/100, moves: 55, ncost: 1566.1726066160916
# Run: 8, iteration: 4/100, moves: 60, ncost: 1458.1388117924894
# Run: 8, iteration: 5/100, moves: 10, ncost: 1456.9427022275434
# Run: 8, iteration: 6/100, moves: 0, ncost: 1456.9427022275434
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 9, iteration: 1/100, moves: 44, ncost: 1737.9116629165162
# Run: 9, iteration: 2/100, moves: 7, ncost: 1736.3608585535405
# Run: 9, iteration: 3/100, moves: 0, ncost: 1736.3608585535405
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 10, iteration: 1/100, moves: 81, ncost: 1466.703998538181
# Run: 10, iteration: 2/100, moves: 12, ncost: 1458.6771811196008
# Run: 10, iteration: 3/100, moves: 5, ncost: 1457.1278442555906
# Run: 10, iteration: 4/100, moves: 0, ncost: 1457.1278442555906
# Best run was number 8

# %%
# Cluster centroids
print(kproto.cluster_centroids_)

# Cluster labels
print(kproto.labels_)
# Out:
# [['0.41818181818181815' '0.12727272727272726' 'female' 'hispanic' 'white'
#   'Associate' 'single' 'Student' 'both' 'Empathetic']
#  ['0.7575757575757576' '2.3737373737373737' 'female' 'non hispanic'
#   'white' 'Bachelor' 'single' 'Retired' 'english' 'Persuasive']
#  ['3.1176470588235294' '1.0588235294117647' 'male' 'hispanic' 'white'
#   'High School' 'married' 'Employed Full time' 'spanish' 'Simplier']]
# [2 0 0 0 0 1 0 1 0 1 0 0 2 0 0 2 1 2 2 0 2 2 2 0 2 2 0 0 0 0 2 2 0 1 2 2 1
#  1 1 1 1 2 2 2 0 0 1 0 1 1 2 0 0 0 0 1 0 1 0 1 0 0 2 0 0 2 1 2 2 0 2 2 2 0
#  2 2 0 0 0 0 2 2 0 1 2 2 1 1 1 1 1 2 2 2 0 0 0 0 1 1 2 0 0 0 0 1 0 1 0 1 0
#  0 2 0 0 2 1 2 2 0 2 2 2 0 2 2 0 0 0 0 2 2 0 1 2 2 1 1 1 1 1 2 2 2 0 0 0 0
#  1 1 2 0 0 0 0 1 0 1 0 1 0 0 2 0 0 2 1 2 2 0 2 2 2 0 2 2 0 0 0 0 2 2 0 1 2
#  2 1 1 1 1 1 2 2 2 0 0 1 0 1 1 2 0 0 0 0 1 0 1 0 1 0 0 2 0 0 2 1 2 2 0 2 2
#  2 0 2 2 0 0 0 0 2 2 0 1 2 2 1 1 1 1 1 2 2 2 0 0 0 0 1 1 2 0 0 0 0 1 0 1 0
#  1 0 0 2 0 0 2 1 2 2 0 2 2 2 0 2 2 0 0 0 0 2 2 0 1 2 2 1 1 1 1 1 2 2 2 0 0
#  0 0 1 1 2 0 0 0 0 1 0 1 0 1 0 0 2 0 0 2 1 2 2 0 2 2 2 0 2 2 0 0 0 0 2 2 0
#  1 2 2 1 1 1 1 1 2 2 2 0 0 0 0 1 1 2 0 0 0 0 1 0 1 0 1 0 0 2 0 0 2 1 2 2 0
#  2 2 2 0 2 2 0 0 0 0 2 2 0 1 2 2 1 1 1 1 1 2 2 2 0 0 1 0 1 1]

# %%
pip install gower
# Out:
# Collecting gower
#   Downloading gower-0.1.2-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: numpy in c:\users\owner\appdata\local\programs\python\python310\lib\site-packages (from gower) (1.25.2)
# Requirement already satisfied: scipy in c:\users\owner\appdata\local\programs\python\python310\lib\site-packages (from gower) (1.11.2)
# Downloading gower-0.1.2-py3-none-any.whl (5.2 kB)
# Installing collected packages: gower
# Successfully installed gower-0.1.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import gower

# %%
gower_distances = gower.gower_matrix(pro_data)

# %%
gower_distances
# Out:
# array([[0.  , 0.68, 0.66, ..., 0.68, 0.46, 0.66],
#        [0.68, 0.  , 0.52, ..., 0.54, 0.56, 0.66],
#        [0.66, 0.52, 0.  , ..., 0.52, 0.64, 0.64],
#        ...,
#        [0.68, 0.54, 0.52, ..., 0.  , 0.56, 0.76],
#        [0.46, 0.56, 0.64, ..., 0.56, 0.  , 0.3 ],
#        [0.66, 0.66, 0.64, ..., 0.76, 0.3 , 0.  ]], dtype=float32)
